# %%
import requests
key = '951b60a07574968b827be9fe5a77a45b'

# %%
#地理编码API 方法:GET
#address为结构化地址信息:省份＋城市＋区县＋城镇＋乡村＋街道＋门牌号码
#可选参数 city

def dilibianma_api(address=str):
    key_last = '&key=' + key
    address_last = 'address=' + address
    bianma_url = 'https://restapi.amap.com/v3/geocode/geo?' + address_last + key_last
    r = requests.get(bianma_url)
    return r.json()

#测试函数(南京大学为例)
dilibianma_api(address='南京大学')
# Out:
# {'status': '1',
#  'info': 'OK',
#  'infocode': '10000',
#  'count': '1',
#  'geocodes': [{'formatted_address': '江苏省南京市栖霞区南京大学',
#    'country': '中国',
#    'province': '江苏省',
#    'citycode': '025',
#    'city': '南京市',
#    'district': '栖霞区',
#    'township': [],
#    'neighborhood': {'name': [], 'type': []},
#    'building': {'name': [], 'type': []},
#    'adcode': '320113',
#    'street': [],
#    'number': [],
#    'location': '118.961365,32.110012',
#    'level': '兴趣点'}]}

# %%
#路径规划API 方法:GET
#北京市东城区正义路2号:116.413384,39.910925
#北京地坛公园:116.421358,39.959903
#origin为出发地，destination为目的地

def lujinguihua_api(origin=str,destination=str):
    key_last = '&key=' + key
    destination_last = '&destination=' + destination
    origin_last = 'origin=' + origin
    lujin_url = 'https://restapi.amap.com/v3/direction/walking?' + origin_last + destination_last + key_last
    r = requests.get(lujin_url)
    return r.json()

#测试函数
lujinguihua_api(origin='116.413384,39.910925',destination='116.421358,39.959903')
# Out:
# {'status': '1',
#  'info': 'ok',
#  'infocode': '10000',
#  'count': '1',
#  'route': {'origin': '116.413384,39.910925',
#   'destination': '116.421358,39.959903',
#   'paths': [{'distance': '6111',
#     'duration': '4889',
#     'steps': [{'instruction': '沿校尉胡同向北步行509米右转',
#       'orientation': '北',
#       'road': '校尉胡同',
#       'distance': '509',
#       'duration': '407',
#       'polyline': '116.413754,39.910911;116.413776,39.911319;116.413785,39.912122;116.413785,39.912122;116.413845,39.912856;116.413845,39.912856;116.413863,39.913273;116.413863,39.913273;116.413876,39.914219;116.413876,39.914219;116.413885,39.914293;116.413885,39.914293;116.413885,39.914596;116.413885,39.914596;116.413885,39.915508',
#       'action': '右转',
#       'assistant_action': [],
#       'walk_type': '0'},
#      {'instruction': '沿金鱼胡同向东步行322米左转',
#       'orientation': '东',
#       'road': '金鱼胡同',
#       'distance': '322',
#       'duration': '258',
#       'polyline': '116.413885,39.915508;116.413993,39.915534;116.413993,39.915534;116.414145,39.915534;116.414145,39.915534;116.414436,39.915534;116.414436,39.915534;116.414952,39.915534;116.414952,39.915534;116.415312,39.915534;116.415312,39.915534;116.415829,39.915534;116.415829,39.915534;116.416289,39.915538;116.416289,39.915538;116.416593,39.915538;116.416593,39.915538;116.416866,39.915538;116.416866,39.915538;116.417057,39.915538;116.417057,39.915538;116.417713,39.915547',
#       'action': '左转',
#       'assistant_action': [],
#       'walk_type': '0'},
#      {'instruction': '沿东四南大街步行966米直行',
#       'orientation': [],
#       'road': '东四南大街',
#       'distance': '966',
#       'duration': '773',
#       'polyline': '116.417713,39.915547;116.417687,39.91625;116.417687,39.91625;116.417687,39.916267;116.417687,39.916267;116.417665,39.916628;116.417665,39.916628;116.417652,39.916892;116.41773,39.916992;116.41773,39.916992;116.41773,39.917036;116.41773,39.917036;116.417704,39.9177;116.417704,39.9177;116.417704,39.917721;116.417704,39.917721;116.417695,39.918003;116.417695,39.918003;116.417665,39.91872;116.417708,39.918811;116.417708,39.918811;116.417708,39.91911;116.417708,39.91911;116.417695,39.919783;116.417695,39.919783;116.417687,39.919909;116.417687,39.919909;116.417665,39.920495;116.417665,39.920495;116.417652,39.920907;116.417652,39.920907;116.417635,39.921172;116.417635,39.921172;116.417582,39.92191;116.417582,39.92191;116.417552,39.922569;116.417552,39.922569;116.417522,39.923958;116.417522,39.923958;116.417504,39.924293',
#       'action': '直行',
#       'assistant_action': [],
#       'walk_type': '0'},
#      {'instruction': '沿东四北大街向北步行106米向右前方行走',
#       'orientation': '北',
#       'road': '东四北大街',
#       'distance': '106',
#       'duration': '85',
#       'polyline': '116.4175,39.924293;116.4175,39.924423;116.4175,39.924423;116.417491,39.92474;116.417491,39.92474;116.417465,39.925252',
#       'action': '向右前方行走',
#       'assistant_action': [],
#       'walk_type': '0'},
#      {'instruction': '步行72米右转',
#       'orientation': [],
#       'road': [],
#       'distance': '72',
#       'duration': '58',
#       'polyline': '116.417461,39.925252;116.417487,39.925269;116.417487,39.925343;116.417487,39.925343;116.417474,39.925621;116.417474,39.925621;116.417465,39.925864;116.417422,39.925885',
#       'action': '右转',
#       'assistant_action': [],
#       'walk_type': '0'},
#      {'instruction': '沿东四北大街向北步行1666米直行',
#       'orientation': '北',
#       'road': '东四北大街',
#       'distance': '1666',
#       'duration': '1333',
#       'polyline': '116.417418,39.925885;116.417391,39.926602;116.417391,39.926602;116.41737,39.927313;116.41737,39.927313;116.417361,39.927387;116.417361,39.927387;116.417352,39.927895;116.417352,39.927895;116.417344,39.927999;116.417344,39.927999;116.417331,39.928746;116.417331,39.928746;116.41737,39.928854;116.417313,39.930126;116.417313,39.930126;116.417313,39.930165;116.417313,39.930165;116.417283,39.930668;116.417283,39.930668;116.417261,39.931432;116.417209,39.931528;116.417209,39.931528;116.417161,39.932279;116.417161,39.932279;116.417161,39.932639;116.417161,39.932639;116.417161,39.932934;116.417161,39.932934;116.417205,39.933056;116.417201,39.933594;116.417201,39.933594;116.417201,39.933715;116.417201,39.933715;116.417179,39.934336;116.417179,39.934336;116.417131,39.934948;116.417079,39.935052;116.417079,39.935052;116.41704,39.935812;116.41704,39.935812;116.417018,39.936398;116.417018,39.936398;116.417001,39.936697;116.417001,39.936697;116.416988,39.937075;116.416988,39.937075;116.416988,39.937135;116.416988,39.937135;116.41694,39.938286;116.41694,39.938286;116.41694,39.938633;116.41694,39.938633;116.416918,39.939232;116.416918,39.939232;116.41691,39.939449;116.41691,39.939449;116.416879,39.940004;116.416879,39.940004;116.416871,39.940109;116.416871,39.940109;116.416858,39.940299;116.416858,39.940299;116.41684,39.940573;116.41684,39.940573;116.416836,39.940768;116.416836,39.940768;116.416836,39.940868;116.416836,39.940868;116.416819,39.940994',
#       'action': '直行',
#       'assistant_action': [],
#       'walk_type': '0'},
#      {'instruction': '沿雍和宫大街向北步行692米向右前方行走',
#       'orientation': '北',
#       'road': '雍和宫大街',
#       'distance': '692',
#       'duration': '554',
#       'polyline': '116.416814,39.940994;116.416814,39.941046;116.416814,39.941046;116.416797,39.941823;116.416797,39.941823;116.416788,39.941979;116.416788,39.941979;116.41678,39.94247;116.41678,39.94247;116.416766,39.942721;116.416766,39.942721;116.416749,39.943225;116.416749,39.943225;116.41674,39.943372;116.41674,39.943372;116.416727,39.943867;116.416727,39.943867;116.416727,39.944123;116.416727,39.944123;116.416697,39.944683;116.416697,39.944683;116.416688,39.945048;116.416688,39.945048;116.416675,39.945343;116.416675,39.945343;116.416675,39.94553;116.416675,39.94553;116.416658,39.946037;116.416658,39.946037;116.416619,39.947092;116.416619,39.947092;116.416619,39.947279',
#       'action': '向右前方行走',
#       'assistant_action': [],
#       'walk_type': '0'},
#      {'instruction': '沿雍和宫大街向北步行208米直行',
#       'orientation': '北',
#       'road': '雍和宫大街',
#       'distance': '208',
#       'duration': '166',
#       'polyline': '116.416615,39.947279;116.416654,39.947478;116.416654,39.947478;116.416645,39.948398;116.416645,39.948398;116.416619,39.948902;116.416619,39.948902;116.416619,39.948958;116.416619,39.948958;116.416584,39.949162',
#       'action': '直行',
#       'assistant_action': [],
#       'walk_type': '0'},
#      {'instruction': '沿和平里西街向北步行199米向右前方行走',
#       'orientation': '北',
#       'road': '和平里西街',
#       'distance': '199',
#       'duration': '159',
#       'polyline': '116.41658,39.949162;116.416445,39.949457;116.416445,39.949457;116.416367,39.950169;116.416363,39.95046;116.416389,39.950673;116.41648,39.950855;116.416549,39.950911',
#       'action': '向右前方行走',
#       'assistant_action': [],
#       'walk_type': '0'},
#      {'instruction': '沿和平里西街向东北步行31米向右前方行走',
#       'orientation': '东北',
#       'road': '和平里西街',
#       'distance': '31',
#       'duration': '25',
#       'polyline': '116.416549,39.950911;116.416762,39.951068;116.416853,39.951098',
#       'action': '向右前方行走',
#       'assistant_action': [],
#       'walk_type': '0'},
#      {'instruction': '沿和平里西街向东步行149米向左前方行走',
#       'orientation': '东',
#       'road': '和平里西街',
#       'distance': '149',
#       'duration': '119',
#       'polyline': '116.416853,39.951098;116.416923,39.951133;116.417118,39.951163;116.417752,39.951202;116.417752,39.951202;116.418003,39.951224;116.418181,39.951263;116.418364,39.951341;116.418485,39.951411',
#       'action': '向左前方行走',
#       'assistant_action': [],
#       'walk_type': '0'},
#      {'instruction': '沿和平里西街向东北步行51米向左前方行走',
#       'orientation': '东北',
#       'road': '和平里西街',
#       'distance': '51',
#       'duration': '41',
#       'polyline': '116.418485,39.951411;116.418598,39.951484;116.418715,39.95158;116.418876,39.951753',
#       'action': '向左前方行走',
#       'assistant_action': [],
#       'walk_type': '0'},
#      {'instruction': '沿和平里西街向北步行907米右转',
#       'orientation': '北',
#       'road': '和平里西街',
#       'distance': '907',
#       'duration': '726',
#       'polyline': '116.418876,39.951753;116.41895,39.951884;116.419006,39.952066;116.41901,39.952227;116.418984,39.952569;116.418984,39.952569;116.41888,39.954023;116.41888,39.954023;116.418945,39.95434;116.418924,39.955143;116.418924,39.955143;116.418832,39.956393;116.418832,39.956393;116.418819,39.956649;116.418819,39.956649;116.418789,39.957127;116.418789,39.957127;116.418772,39.957313;116.418772,39.957313;116.418728,39.957895;116.418728,39.957895;116.41872,39.957964;116.41872,39.957964;116.41872,39.958025;116.41872,39.958025;116.418681,39.958398;116.418681,39.958398;116.418659,39.959201;116.418659,39.959201;116.41865,39.959332;116.41865,39.959332;116.418602,39.959952',
#       'action': '右转',
#       'assistant_action': [],
#       'walk_type': '0'},
#      {'instruction': '向东步行233米到达目的地',
#       'orientation': '东',
#       'road': [],
#       'distance': '233',
#       'duration': '186',
#       'polyline': '116.418598,39.959952;116.418767,39.959931;116.418767,39.959931;116.418889,39.959922;116.419631,39.959944;116.419631,39.959944;116.420078,39.959961;116.420078,39.959961;116.420551,39.959978;116.420551,39.959978;116.421354,39.959991',
#       'action': [],
#       'assistant_action': '到达目的地',
#       'walk_type': '0'}]}]}}

# %%
#行政区域查询API 方法:GET
#城市地理编码的高德官方下载地址：https://lbs.amap.com/api/webservice/download
#南京市 adcode:320100  citycode:025
#keyword为查询关键字（行政区名称、citycode、adcode）


def xingzhengquyuchaxun_api(keywords=str,subdistrict=str):
    key_last = '&key=' + key
    subdistrict_last = '&subdistrict=' + subdistrict
    keywords_last = 'keywords=' + keywords
    xingzheng_url = 'https://restapi.amap.com/v3/config/district?' + keywords_last + subdistrict_last + key_last
    r = requests.get(xingzheng_url)
    return r.json()

#测试函数，以南京为例
xingzhengquyuchaxun_api(keywords = '320100', subdistrict = '1')
# Out:
# {'status': '1',
#  'info': 'OK',
#  'infocode': '10000',
#  'count': '1',
#  'suggestion': {'keywords': [], 'cities': []},
#  'districts': [{'citycode': '025',
#    'adcode': '320100',
#    'name': '南京市',
#    'center': '118.767413,32.041544',
#    'level': 'city',
#    'districts': [{'citycode': '025',
#      'adcode': '320115',
#      'name': '江宁区',
#      'center': '118.850621,31.953418',
#      'level': 'district',
#      'districts': []},
#     {'citycode': '025',
#      'adcode': '320111',
#      'name': '浦口区',
#      'center': '118.625307,32.05839',
#      'level': 'district',
#      'districts': []},
#     {'citycode': '025',
#      'adcode': '320114',
#      'name': '雨花台区',
#      'center': '118.77207,31.995946',
#      'level': 'district',
#      'districts': []},
#     {'citycode': '025',
#      'adcode': '320117',
#      'name': '溧水区',
#      'center': '119.028732,31.653061',
#      'level': 'district',
#      'districts': []},
#     {'citycode': '025',
#      'adcode': '320118',
#      'name': '高淳区',
#      'center': '118.87589,31.327132',
#      'level': 'district',
#      'districts': []},
#     {'citycode': '025',
#      'adcode': '320116',
#      'name': '六合区',
#      'center': '118.85065,32.340655',
#      'level': 'district',
#      'districts': []},
#     {'citycode': '025',
#      'adcode': '320105',
#      'name': '建邺区',
#      'center': '118.732688,32.004538',
#      'level': 'district',
#      'districts': []},
#     {'citycode': '025',
#      'adcode': '320106',
#      'name': '鼓楼区',
#      'center': '118.769739,32.066966',
#      'level': 'district',
#      'districts': []},
#     {'citycode': '025',
#      'adcode': '320104',
#      'name': '秦淮区',
#      'center': '118.786088,32.033818',
#      'level': 'district',
#      'districts': []},
#     {'citycode': '025',
#      'adcode': '320102',
#      'name': '玄武区',
#      'center': '118.792199,32.050678',
#      'level': 'district',
#      'districts': []},
#     {'citycode': '025',
#      'adcode': '320113',
#      'name': '栖霞区',
#      'center': '118.808702,32.102147',
#      'level': 'district',
#      'districts': []}]}]}

# %%
#搜索POI API 方法:GET
#keywords：多个关键字用“|”分割，types：分类代码 或 汉字（若用汉字，请严格按照附件之中的汉字填写）
#这里选取了南京餐饮服务为例

def sousuopoi_api(keyword=str,types=str):
    types_last = '&types=' + types
    keyword_last = 'keywords=' + keyword
    key_last = '&key=' + key
    poi_url = 'https://restapi.amap.com/v3/place/text?' + keyword_last + types_last + key_last + '&citylimit=true'
    r = requests.get(poi_url)
    return r.json()

sousuopoi_api(keyword="南京大学",types='餐饮相关')
# Out:
# {'status': '1',
#  'count': '858',
#  'info': 'OK',
#  'infocode': '10000',
#  'suggestion': {'keywords': [], 'cities': []},
#  'pois': [{'id': 'B0FFHKX1XF',
#    'parent': 'B0FFIBD1SN',
#    'childtype': '309',
#    'name': '南京审计大学润园食堂',
#    'type': '餐饮服务;餐饮相关场所;餐饮相关',
#    'typecode': '050000',
#    'biz_type': 'diner',
#    'address': '雨山西路86号',
#    'location': '118.608298,32.066650',
#    'tel': [],
#    'distance': [],
#    'biz_ext': {'rating': '4.0', 'cost': '12.00', 'meal_ordering': '0'},
#    'pname': '江苏省',
#    'cityname': '南京市',
#    'adname': '浦口区',
#    'importance': [],
#    'shopid': [],
#    'shopinfo': '0',
#    'poiweight': [],
#    'photos': [{'url': 'http://store.is.autonavi.com/showpic/6340320a92fb6ba8a1b12c660d2b4326',
#      'provider': [],
#      'title': []},
#     {'url': 'http://store.is.autonavi.com/showpic/88d605ff9690b58b8a69df96f7aab224',
#      'provider': [],
#      'title': []},
#     {'url': 'http://store.is.autonavi.com/showpic/83312768fc8d9a9f49248799fdc09951',
#      'provider': [],
#      'title': []}]},
#   {'id': 'B0FFJ1JI3R',
#    'parent': [],
#    'childtype': [],
#    'name': '南京审计大学润园餐厅',
#    'type': '餐饮服务;餐饮相关场所;餐饮相关',
#    'typecode': '050000',
#    'biz_type': 'diner',
#    'address': '金陵名人居28号501室',
#    'location': '118.741863,32.062835',
#    'tel': [],
#    'distance': [],
#    'biz_ext': {'rating': [], 'cost': [], 'meal_ordering': '0'},
#    'pname': '江苏省',
#    'cityname': '南京市',
#    'adname': '鼓楼区',
#    'importance': [],
#    'shopid': [],
#    'shopinfo': '0',
#    'poiweight': [],
#    'photos': [{'url': 'http://store.is.autonavi.com/showpic/c9a3ecade6014499f1e013b0d59701c7',
#      'provider': [],
#      'title': []},
#     {'url': 'http://store.is.autonavi.com/showpic/e3cbe570d7d4eaaa932801078abf60cf',
#      'provider': [],
#      'title': []},
#     {'url': 'http://store.is.autonavi.com/showpic/0f81c759a68530abf6d47a6fecc4bb88',
#      'provider': [],
#      'title': []}]},
#   {'id': 'B0FFG7PQWW',
#    'parent': 'B001905144',
#    'childtype': '309',
#    'name': '南京林业大学-二村食堂',
#    'type': '餐饮服务;餐饮相关场所;餐饮相关',
#    'typecode': '050000',
#    'biz_type': 'diner',
#    'address': '龙蟠路159号南京林业大学二村',
#    'location': '118.818757,32.078484',
#    'tel': [],
#    'distance': [],
#    'biz_ext': {'rating': '4.0', 'cost': '11.00', 'meal_ordering': '0'},
#    'pname': '江苏省',
#    'cityname': '南京市',
#    'adname': '玄武区',
#    'importance': [],
#    'shopid': [],
#    'shopinfo': '0',
#    'poiweight': [],
#    'photos': []},
#   {'id': 'B0FFJGZWV8',
#    'parent': 'B001905144',
#    'childtype': '309',
#    'name': '南京林业大学-一村食堂',
#    'type': '餐饮服务;餐饮相关场所;餐饮相关',
#    'typecode': '050000',
#    'biz_type': 'diner',
#    'address': '龙蟠路159号南京林业大学一村(近足球场)',
#    'location': '118.813415,32.080813',
#    'tel': '025-85427083',
#    'distance': [],
#    'biz_ext': {'rating': '3.5', 'cost': '20.00', 'meal_ordering': '0'},
#    'pname': '江苏省',
#    'cityname': '南京市',
#    'adname': '玄武区',
#    'importance': [],
#    'shopid': [],
#    'shopinfo': '0',
#    'poiweight': [],
#    'photos': [{'url': 'http://store.is.autonavi.com/showpic/ee1b2d4f8c5084a14ec3394c065af61d',
#      'provider': [],
#      'title': []},
#     {'url': 'http://store.is.autonavi.com/showpic/593932f3a8b0d331d73abb4dccc79419',
#      'provider': [],
#      'title': []},
#     {'url': 'http://store.is.autonavi.com/showpic/9fda20b0e0e1d3923c1e7ab81733d7b6',
#      'provider': [],
#      'title': []}]},
#   {'id': 'B0FFHFANQF',
#    'parent': [],
#    'childtype': [],
#    'name': '南京邮电大学第2食堂',
#    'type': '餐饮服务;餐饮相关场所;餐饮相关',
#    'typecode': '050000',
#    'biz_type': 'diner',
#    'address': '文苑路9号(近图书馆)',
#    'location': '118.932915,32.111832',
#    'tel': [],
#    'distance': [],
#    'biz_ext': {'rating': '3.5', 'cost': '13.00', 'meal_ordering': '0'},
#    'pname': '江苏省',
#    'cityname': '南京市',
#    'adname': '栖霞区',
#    'importance': [],
#    'shopid': [],
#    'shopinfo': '0',
#    'poiweight': [],
#    'photos': [{'url': 'http://store.is.autonavi.com/showpic/dbc7a5ab8ab9ba75b7bafb2dd23af81b',
#      'provider': [],
#      'title': []},
#     {'url': 'http://store.is.autonavi.com/showpic/3614ba880d6f3db6d6c2820d4b0ed6fd',
#      'provider': [],
#      'title': []},
#     {'url': 'http://store.is.autonavi.com/showpic/06111ea4456eda40223512873762b129',
#      'provider': [],
#      'title': []}]},
#   {'id': 'B0FFIN467M',
#    'parent': 'B00190AYXV',
#    'childtype': '309',
#    'name': '南京工业大学北苑食堂',
#    'type': '餐饮服务;餐饮相关场所;餐饮相关',
#    'typecode': '050000',
#    'biz_type': 'diner',
#    'address': '浦珠南路30号',
#    'location': '118.638897,32.080211',
#    'tel': [],
#    'distance': [],
#    'biz_ext': {'rating': [], 'cost': [], 'meal_ordering': '0'},
#    'pname': '江苏省',
#    'cityname': '南京市',
#    'adname': '浦口区',
#    'importance': [],
#    'shopid': [],
#    'shopinfo': '0',
#    'poiweight': [],
#    'photos': []},
#   {'id': 'B0FFHXT4R2',
#    'parent': 'B00190Z4MY',
#    'childtype': '309',
#    'name': '南京邮电大学仙林校区2食堂',
#    'type': '餐饮服务;餐饮相关场所;餐饮相关',
#    'typecode': '050000',
#    'biz_type': 'diner',
#    'address': '仙林文苑路9号南京邮电大学(近图书馆)',
#    'location': '118.933120,32.111817',
#    'tel': [],
#    'distance': [],
#    'biz_ext': {'rating': '3.8', 'cost': '11.00', 'meal_ordering': '0'},
#    'pname': '江苏省',
#    'cityname': '南京市',
#    'adname': '栖霞区',
#    'importance': [],
#    'shopid': [],
#    'shopinfo': '0',
#    'poiweight': [],
#    'photos': []},
#   {'id': 'B0FFJ55Z3G',
#    'parent': 'B00190YM7S',
#    'childtype': '309',
#    'name': '南京财经大学(仙林校区)-东苑食堂',
#    'type': '餐饮服务;餐饮相关场所;餐饮相关',
#    'typecode': '050000',
#    'biz_type': 'diner',
#    'address': '文苑路3号南京财经大学仙林校区内(近学海路)',
#    'location': '118.926582,32.112044',
#    'tel': [],
#    'distance': [],
#    'biz_ext': {'rating': '4.5', 'cost': '13.00', 'meal_ordering': '0'},
#    'pname': '江苏省',
#    'cityname': '南京市',
#    'adname': '栖霞区',
#    'importance': [],
#    'shopid': [],
#    'shopinfo': '0',
#    'poiweight': [],
#    'photos': [{'url': 'http://store.is.autonavi.com/showpic/5b9fd9efab51be5f2d609dcfef640881',
#      'provider': [],
#      'title': []},
#     {'url': 'http://store.is.autonavi.com/showpic/8be252474c6b91733268d8e87e7670b1',
#      'provider': [],
#      'title': []},
#     {'url': 'http://store.is.autonavi.com/showpic/afb99450751da9d5efab1bfabb31c5fa',
#      'provider': [],
#      'title': []}]},
#   {'id': 'B0FFHJ7J61',
#    'parent': [],
#    'childtype': [],
#    'name': '南京师范大学泰州学院学生一食堂',
#    'type': '餐饮服务;餐饮相关场所;餐饮相关',
#    'typecode': '050000',
#    'biz_type': 'diner',
#    'address': '育才路南京师范大学泰州学院内',
#    'location': '119.943457,32.477806',
#    'tel': [],
#    'distance': [],
#    'biz_ext': {'rating': '3.4', 'cost': [], 'meal_ordering': '0'},
#    'pname': '江苏省',
#    'cityname': '泰州市',
#    'adname': '海陵区',
#    'importance': [],
#    'shopid': [],
#    'shopinfo': '0',
#    'poiweight': [],
#    'photos': [{'url': 'http://store.is.autonavi.com/showpic/bc8116d2bc327a3e35860fcda2a59ad3',
#      'provider': [],
#      'title': []}]},
#   {'id': 'B0FFHUM34W',
#    'parent': 'B0FFH8MH83',
#    'childtype': '309',
#    'name': '南京中医药大学汉中门校区食堂',
#    'type': '餐饮服务;餐饮相关场所;餐饮相关',
#    'typecode': '050000',
#    'biz_type': 'diner',
#    'address': '汉中门汉中路282号',
#    'location': '118.767360,32.043274',
#    'tel': '15851800794',
#    'distance': [],
#    'biz_ext': {'rating': '4.0', 'cost': '14.00', 'meal_ordering': '0'},
#    'pname': '江苏省',
#    'cityname': '南京市',
#    'adname': '鼓楼区',
#    'importance': [],
#    'shopid': [],
#    'shopinfo': '0',
#    'poiweight': [],
#    'photos': [{'url': 'http://store.is.autonavi.com/showpic/df44e4b0253289ef1429138a23aa2926',
#      'provider': [],
#      'title': []},
#     {'url': 'http://store.is.autonavi.com/showpic/486f340be286498646c978f93ee724a3',
#      'provider': [],
#      'title': '皮蛋豆腐'},
#     {'url': 'http://store.is.autonavi.com/showpic/9bcb8885ef3a8e01fb10031339217963',
#      'provider': [],
#      'title': []}]},
#   {'id': 'B0FFID1DD3',
#    'parent': 'B00190BMS3',
#    'childtype': '309',
#    'name': '南京信息工程大学-1960教工食堂',
#    'type': '餐饮服务;餐饮相关场所;餐饮相关',
#    'typecode': '050000',
#    'biz_type': 'diner',
#    'address': '宁6路219号南京信息工程大学',
#    'location': '118.716415,32.204726',
#    'tel': [],
#    'distance': [],
#    'biz_ext': {'rating': '3.5', 'cost': '14.00', 'meal_ordering': '0'},
#    'pname': '江苏省',
#    'cityname': '南京市',
#    'adname': '浦口区',
#    'importance': [],
#    'shopid': [],
#    'shopinfo': '0',
#    'poiweight': [],
#    'photos': [{'url': 'http://store.is.autonavi.com/showpic/27abd01a3004046f638338a9cff5cdc1',
#      'provider': [],
#      'title': []},
#     {'url': 'http://store.is.autonavi.com/showpic/ce67df89191f2d509ec5f4fecc321939',
#      'provider': [],
#      'title': []},
#     {'url': 'http://store.is.autonavi.com/showpic/667aa5216e571e56ad432634664f6d85',
#      'provider': [],
#      'title': []}]},
#   {'id': 'B0FFJIDPL1',
#    'parent': 'B00190CU51',
#    'childtype': '309',
#    'name': '南京师范大学新北区第1学生食堂',
#    'type': '餐饮服务;餐饮相关场所;餐饮相关',
#    'typecode': '050000',
#    'biz_type': 'diner',
#    'address': '仙林街道仙林大学城学林路2号',
#    'location': '118.908844,32.116037',
#    'tel': [],
#    'distance': [],
#    'biz_ext': {'rating': '3.5', 'cost': '15.00', 'meal_ordering': '0'},
#    'pname': '江苏省',
#    'cityname': '南京市',
#    'adname': '栖霞区',
#    'importance': [],
#    'shopid': [],
#    'shopinfo': '0',
#    'poiweight': [],
#    'photos': [{'url': 'http://store.is.autonavi.com/showpic/5d4ec3632cdedf23bfa984a6de7906bf',
#      'provider': [],
#      'title': []},
#     {'url': 'http://store.is.autonavi.com/showpic/40dafef0bb529a77fafebbdce611ddb3',
#      'provider': [],
#      'title': []},
#     {'url': 'http://store.is.autonavi.com/showpic/41970dc4f9403a8b15ea1dddd64ce0cc',
#      'provider': [],
#      'title': []}]},
#   {'id': 'B0FFHWEOTQ',
#    'parent': 'B020B01CHG',
#    'childtype': '309',
#    'name': '南京理工大学泰州科技学院-第1食堂',
#    'type': '餐饮服务;餐饮相关场所;餐饮相关',
#    'typecode': '050000',
#    'biz_type': 'diner',
#    'address': '梅兰东路9号',
#    'location': '119.944481,32.464363',
#    'tel': [],
#    'distance': [],
#    'biz_ext': {'rating': '3.0', 'cost': [], 'meal_ordering': '0'},
#    'pname': '江苏省',
#    'cityname': '泰州市',
#    'adname': '海陵区',
#    'importance': [],
#    'shopid': [],
#    'shopinfo': '0',
#    'poiweight': [],
#    'photos': [{'url': 'http://store.is.autonavi.com/showpic/e10522cad876e29d9dc500df170de52f',
#      'provider': [],
#      'title': []},
#     {'url': 'http://store.is.autonavi.com/showpic/d828d4111eae76da6d81f3a5c8150edb',
#      'provider': [],
#      'title': []},
#     {'url': 'http://store.is.autonavi.com/showpic/5231e335db2468a72bfd6446e18d47f0',
#      'provider': [],
#      'title': []}]},
#   {'id': 'B0FFITUW2N',
#    'parent': 'B00190BJ7Q',
#    'childtype': '309',
#    'name': '南京航空航天大学金城学院一食堂',
#    'type': '餐饮服务;餐饮相关场所;餐饮相关',
#    'typecode': '050000',
#    'biz_type': 'diner',
#    'address': [],
#    'location': '118.883665,31.698217',
#    'tel': [],
#    'distance': [],
#    'biz_ext': {'rating': [], 'cost': [], 'meal_ordering': '0'},
#    'pname': '江苏省',
#    'cityname': '南京市',
#    'adname': '江宁区',
#    'importance': [],
#    'shopid': [],
#    'shopinfo': '0',
#    'poiweight': [],
#    'photos': []},
#   {'id': 'B0FFLHKAQ7',
#    'parent': 'B00190BMS3',
#    'childtype': '309',
#    'name': '南京信息工程大学西苑蜜雪冰城',
#    'type': '餐饮服务;餐饮相关场所;餐饮相关',
#    'typecode': '050000',
#    'biz_type': 'diner',
#    'address': '南京信息工程大学西苑新食堂二楼',
#    'location': '118.706343,32.204010',
#    'tel': '18094459575',
#    'distance': [],
#    'biz_ext': {'rating': [], 'cost': [], 'meal_ordering': '0'},
#    'pname': '江苏省',
#    'cityname': '南京市',
#    'adname': '浦口区',
#    'importance': [],
#    'shopid': [],
#    'shopinfo': '0',
#    'poiweight': [],
#    'photos': [{'url': 'http://store.is.autonavi.com/showpic/c670f03ce7714f107e5cc68bbacd65ea',
#      'provider': [],
#      'title': []},
#     {'url': 'http://store.is.autonavi.com/showpic/ce1eedda94841d80a19e8759f1ecaa8b',
#      'provider': [],
#      'title': []},
#     {'url': 'http://store.is.autonavi.com/showpic/327767ff48b99822c8faa6364145ffa9',
#      'provider': [],
#      'title': []}]},
#   {'id': 'B0FFI7UDNB',
#    'parent': 'B00190BMS3',
#    'childtype': '309',
#    'name': '南京信息工程大学中苑老食堂',
#    'type': '餐饮服务;餐饮相关场所;餐饮相关',
#    'typecode': '050000',
#    'biz_type': 'diner',
#    'address': '龙山北路4号',
#    'location': '118.716526,32.202398',
#    'tel': [],
#    'distance': [],
#    'biz_ext': {'rating': '3.0', 'cost': [], 'meal_ordering': '0'},
#    'pname': '江苏省',
#    'cityname': '南京市',
#    'adname': '浦口区',
#    'importance': [],
#    'shopid': [],
#    'shopinfo': '0',
#    'poiweight': [],
#    'photos': []},
#   {'id': 'B0FFIYAUCM',
#    'parent': 'B00190CRZK',
#    'childtype': '309',
#    'name': '南京航空航天大学将军路校区1食堂',
#    'type': '餐饮服务;餐饮相关场所;餐饮相关',
#    'typecode': '050000',
#    'biz_type': 'diner',
#    'address': '佛城西路康厚街群创光电93号',
#    'location': '118.784600,31.946970',
#    'tel': [],
#    'distance': [],
#    'biz_ext': {'rating': '3.5', 'cost': '12.00', 'meal_ordering': '0'},
#    'pname': '江苏省',
#    'cityname': '南京市',
#    'adname': '江宁区',
#    'importance': [],
#    'shopid': [],
#    'shopinfo': '0',
#    'poiweight': [],
#    'photos': [{'url': 'http://store.is.autonavi.com/showpic/16881a9fd3202fa5565e54b7f775454e',
#      'provider': [],
#      'title': []},
#     {'url': 'http://store.is.autonavi.com/showpic/1864eccdeb3045bfb3067bb974cee164',
#      'provider': [],
#      'title': []},
#     {'url': 'http://store.is.autonavi.com/showpic/24a1617aae56aec1620ca0db88176fc6',
#      'provider': [],
#      'title': []}]},
#   {'id': 'B0FFKX2O8L',
#    'parent': [],
#    'childtype': [],
#    'name': '蒙古烧烤·火锅(南京工业大学店)',
#    'type': '餐饮服务;餐饮相关场所;餐饮相关',
#    'typecode': '050000',
#    'biz_type': 'diner',
#    'address': '龙华路2号龙华大酒店西侧门面3号商铺',
#    'location': '118.640864,32.071832',
#    'tel': '13605151868',
#    'distance': [],
#    'biz_ext': {'rating': '3.5', 'cost': '78.00', 'meal_ordering': '0'},
#    'pname': '江苏省',
#    'cityname': '南京市',
#    'adname': '浦口区',
#    'importance': [],
#    'shopid': [],
#    'shopinfo': '0',
#    'poiweight': [],
#    'photos': [{'url': 'http://store.is.autonavi.com/showpic/0380c51e19f34dbf21fb42b486dc787f',
#      'provider': [],
#      'title': '特级雪花牛仔骨'},
#     {'url': 'http://store.is.autonavi.com/showpic/08ffe85137c8a52862168f2cffee129e',
#      'provider': [],
#      'title': '特级雪花牛仔骨'},
#     {'url': 'http://store.is.autonavi.com/showpic/fd1f9924453ca0f0bdfee7724a9c2ff9',
#      'provider': [],
#      'title': []}]},
#   {'id': 'B0FFJTOCFH',
#    'parent': 'B0FFI55XFM',
#    'childtype': '202',
#    'name': 'Helens小酒馆(南京浦口大学城店)',
#    'type': '餐饮服务;餐饮相关场所;餐饮相关',
#    'typecode': '050000',
#    'biz_type': 'diner',
#    'address': '江浦街道海都路8号08幢1-55室st广场2层',
#    'location': '118.639732,32.069377',
#    'tel': '025-58259672',
#    'distance': [],
#    'biz_ext': {'rating': '4.0', 'cost': '75.00', 'meal_ordering': '0'},
#    'pname': '江苏省',
#    'cityname': '南京市',
#    'adname': '浦口区',
#    'importance': [],
#    'shopid': [],
#    'shopinfo': '0',
#    'poiweight': [],
#    'photos': [{'url': 'http://store.is.autonavi.com/showpic/21d20ed2cbb72fed53b6bd07321e7057',
#      'provider': [],
#      'title': []},
#     {'url': 'http://store.is.autonavi.com/showpic/faf48df32afa406de862928b91f8af54',
#      'provider': [],
#      'title': []},
#     {'url': 'http://store.is.autonavi.com/showpic/89e8cc731da9baa97aeb4c7f7976c3eb',
#      'provider': [],
#      'title': []}]},
#   {'id': 'B0FFKTBU6G',
#    'parent': [],
#    'childtype': [],
#    'name': '蜜雪冰城新鲜冰淇淋·茶饮(南京邮电大学店)',
#    'type': '餐饮服务;餐饮相关场所;餐饮相关',
#    'typecode': '050000',
#    'biz_type': 'diner',
#    'address': '仙林街道文苑路9号南京邮电大学仙林校区梅苑01105号',
#    'location': '118.933042,32.109360',
#    'tel': '13770779392',
#    'distance': [],
#    'biz_ext': {'rating': '4.0', 'cost': [], 'meal_ordering': '0'},
#    'pname': '江苏省',
#    'cityname': '南京市',
#    'adname': '栖霞区',
#    'importance': [],
#    'shopid': [],
#    'shopinfo': '0',
#    'poiweight': [],
#    'photos': []}]}

# %%
#ip查询 API 方法:GET

def ipchaxun_api(ip=str):
    key_last = '&key=' + key
    ip_last = "ip_last=" + ip
    ip_url = 'https://restapi.amap.com/v3/ip?' + ip_last + key_last
    r = requests.get(ip_url)
    return r.json()

ipchaxun_api(ip='210.21.79.245')
# Out:
# {'status': '1',
#  'info': 'OK',
#  'infocode': '10000',
#  'province': '广东省',
#  'city': '汕头市',
#  'adcode': '440500',
#  'rectangle': '116.6117942,23.28637076;116.8215644,23.45797106'}

# %%
# 静态地图 API 方法:GET

def jingtaimap_api(location=str,zoom=int):
    zoom_last = "&zoom=" + str(zoom)
    location_last = "location=" + location
    key_last = '&key=' + key
    map_url = "https://restapi.amap.com/v3/staticmap?" + location_last + zoom_last + key_last
    r = requests.get(map_url)
    return r.url

jingtaimap_api(location="32.0712290800,118.7999725300",zoom=16)
# Out:
# 'https://restapi.amap.com/v3/staticmap?location=32.0712290800,118.7999725300&zoom=16&key=951b60a07574968b827be9fe5a77a45b'

# %%
# 天气查询 API   方法:GET

def tianqichaxun_api(city=int):
    city_last = "city=" + str(city)
    key_last = '&key=' + key
    tianqi_url = 'https://restapi.amap.com/v3/weather/weatherInfo?' + city_last + key_last
    r = requests.get(tianqi_url)
    return r.json()

tianqichaxun_api(city=320100)
# Out:
# {'status': '1',
#  'count': '1',
#  'info': 'OK',
#  'infocode': '10000',
#  'lives': [{'province': '江苏',
#    'city': '南京市',
#    'adcode': '320100',
#    'weather': '多云',
#    'temperature': '18',
#    'winddirection': '西',
#    'windpower': '≤3',
#    'humidity': '27',
#    'reporttime': '2020-04-23 18:24:13'}]}

# %%
# 输入提示 API  方法:GET

def shurutishi_api(keywords=str,city=int):
    key_last = '&key=' + key
    keywords_last = "keywords=" + keywords
    city_last = "&city=" + str(city)
    data = "&citylimit=true"
    shuru_url = 'https://restapi.amap.com/v3/assistant/inputtips?' + keywords_last + data + city_last + key_last 
    r = requests.get(shuru_url)
    return r.json()

shurutishi_api(keywords='美食',city=320100)
# Out:
# {'status': '1',
#  'count': '10',
#  'info': 'OK',
#  'infocode': '10000',
#  'tips': [{'id': 'B00190B3T5',
#    'name': '肯德基(汉中店)',
#    'district': '江苏省南京市秦淮区',
#    'adcode': '320104',
#    'location': '118.767793,32.042674',
#    'address': '汉中路209-4号',
#    'typecode': '050301',
#    'city': []},
#   {'id': 'B001909P01',
#    'name': '阿拉丁新疆风味餐厅(罗廊巷店)',
#    'district': '江苏省南京市秦淮区',
#    'adcode': '320104',
#    'location': '118.771157,32.041070',
#    'address': '汉中路罗廊巷43号',
#    'typecode': '050121',
#    'city': []},
#   {'id': 'B0FFF2HHT4',
#    'name': '江南公社(莫愁湖店)',
#    'district': '江苏省南京市建邺区',
#    'adcode': '320105',
#    'location': '118.765388,32.038876',
#    'address': '莫愁湖东路52号',
#    'typecode': '050108',
#    'city': []},
#   {'id': 'B001911HF5',
#    'name': '越南餐厅(萍聚村店)',
#    'district': '江苏省南京市鼓楼区',
#    'adcode': '320106',
#    'location': '118.766078,32.044052',
#    'address': '汉中门萍聚村5号7幢102',
#    'typecode': '050206',
#    'city': []},
#   {'id': 'B00190BMAV',
#    'name': '鸡鸣汤包(新街口明瓦廊店)',
#    'district': '江苏省南京市秦淮区',
#    'adcode': '320104',
#    'location': '118.771318,32.039834',
#    'address': '侯家桥77-2号',
#    'typecode': '050100',
#    'city': []},
#   {'id': 'B0FFG4D8T7',
#    'name': '一郎の料理',
#    'district': '江苏省南京市鼓楼区',
#    'adcode': '320106',
#    'location': '118.772348,32.043918',
#    'address': '牌楼巷怡景花园18号',
#    'typecode': '050202',
#    'city': []},
#   {'id': 'B001911R2J',
#    'name': '庆善园石锅料理(牌楼巷店)',
#    'district': '江苏省南京市鼓楼区',
#    'adcode': '320106',
#    'location': '118.771585,32.043096',
#    'address': '牌楼巷27-3号',
#    'typecode': '050203',
#    'city': []},
#   {'id': 'B0FFHODFLF',
#    'name': '泰食斋泰式时尚餐厅(石鼓路店)',
#    'district': '江苏省南京市秦淮区',
#    'adcode': '320104',
#    'location': '118.770402,32.041585',
#    'address': '石鼓路222号(金丝利酒店后边)',
#    'typecode': '050206',
#    'city': []},
#   {'id': 'B0FFH0F39F',
#    'name': '云南李记罐罐米线饵丝小吃(汉中门金鹰店)',
#    'district': '江苏省南京市建邺区',
#    'adcode': '320105',
#    'location': '118.762306,32.040153',
#    'address': '汉中门大街17-3号',
#    'typecode': '050114',
#    'city': []},
#   {'id': 'B00190D0LC',
#    'name': '全美精菜馆',
#    'district': '江苏省南京市秦淮区',
#    'adcode': '320104',
#    'location': '118.770686,32.040874',
#    'address': '罗廊巷39号(金丝利喜来登酒店南50米)',
#    'typecode': '050100',
#    'city': []}]}

# %%
def jiaotong_api(rectangle=str,level=int):
    rectangle_last = "rectangle=" + rectangle
    key_last = '&key=' + key
    level_last = "&level=" + str(level)
    jiaotong_url = "https://restapi.amap.com/v3/traffic/status/rectangle?" + rectangle_last + level_last + key_last
    r = requests.get(jiaotong_url)
    return r.json()

jiaotong_api(rectangle="116.351147,39.966309;116.357134,39.968727",level=3)
# Out:
# {'status': '1',
#  'info': 'OK',
#  'infocode': '10000',
#  'trafficinfo': {'description': '北三环路：从苏州桥到安华桥畅通。',
#   'evaluation': {'expedite': '100.00%',
#    'congested': '0.00%',
#    'blocked': '0.00%',
#    'unknown': '0.00%',
#    'status': '1',
#    'description': '整体畅通'}}}

# %%
import json
def dili_api(name=str,center=str,radius=int,valid_time=None,repeat="Mon,Tues,Wed,Thur,Fri,Sat,Sun"):
    headers = {
        "content-type":"application/json"
    }
    body= {
        "name": name,
        "center": center,
        "radius": str(radius),
        "enable": "true",
        "valid_time": valid_time,
        "repeat": repeat,
        }
    key_last = 'key=' + key
    dili_url = "https://restapi.amap.com/v4/geofence/meta?" + key_last
    r = requests.post(dili_url,data=json.dumps(body),headers=headers)
    return r.json()

dili_api("Lking","115.672126,38.817129",1000)
# Out:
# {'data': {'gid': '261d3238-9491-46cd-8463-c8579177a111',
#   'id': '0',
#   'message': '成功',
#   'status': '0'},
#  'errcode': 0,
#  'errdetail': None,
#  'errmsg': 'OK',
#  'ext': None}
